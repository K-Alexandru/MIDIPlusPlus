# %% [markdown]
# # This converter has moved to QuartzMIDI
#
# This notebook no longer works.
#
# Audio to MIDI is now built into QuartzMIDI.
#
# ## [PROJECT_URL](PROJECT_URL)

# %%
#@title QuartzMIDI
from IPython.display import HTML, display

URL = "PROJECT_URL"
display(HTML(f'<a href="{URL}" target="_blank" style="font-size:22px">{URL}</a>'))
